# %% [markdown]
# - **Country or region** — название страны или региона;
# - **Score** — уровень счастья (целевой признак);
# - **GDP per capita** — показатель валового внутреннего продукта на душу населения;
# - **Social support** — уровень социальной поддержки;
# - **Healthy life expectancy** — ожидаемая продолжительность здоровой жизни;
# - **Freedom to make life choices** — уровень свободы при выборе жизненного пути;
# - **Generosity** — уровень щедрости населения;
# - **Perceptions of corruption** — восприятие коррупции в стране.

# %%
import pandas as pd
df = pd.read_csv('/kaggle/input/world-happiness/2019.csv')
df.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df.describe()
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# 25%                   0.547750                      0.308000    0.108750
# 50%                   0.789000                      0.417000    0.177500
# 75%                   0.881750                      0.507250    0.248250
# max                   1.141000                      0.631000    0.566000
#
#        Perceptions of corruption
# count                 156.000000
# mean                    0.110603
# std                     0.094538
# min                     0.000000
# 25%                     0.047000
# 50%                     0.085500
# 75%                     0.141250
# max                     0.453000

# %%
df.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
df.columns = [c.strip().replace(' ', '_').lower() for c in df.columns]

# %%
df.columns
# Out:
# Index(['overall_rank', 'country_or_region', 'score', 'gdp_per_capita',
#        'social_support', 'healthy_life_expectancy',
#        'freedom_to_make_life_choices', 'generosity',
#        'perceptions_of_corruption'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
top_10 = df.sort_values('score', ascending=False).head(10)

# %%
top_10
# Out:
#    overall_rank country_or_region  score  gdp_per_capita  social_support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
# 5                    1.052                         0.572       0.263
# 6                    1.009                         0.574       0.267
# 7                    1.026                         0.585       0.330
# 8                    1.039                         0.584       0.285
# 9                    1.016                         0.532       0.244
#
#    perceptions_of_corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298
# 5                      0.343
# 6                      0.373
# 7                      0.380
# 8                      0.308
# 9                      0.226

# %%
sns.barplot(x='score', y='country_or_region', data=top_10)
plt.title('Топ 10 самых счастливых стран в 2019 годы')
# Out:
# Text(0.5, 1.0, 'Топ 10 самых счастливых стран в 2019 годы')

# %%
numeric_df = df.select_dtypes(include='number')

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Корреляционная матрица числовых признаков")
plt.show()

# %%
sns.scatterplot(x='gdp_per_capita', y='score', data=df)
plt.title("Счастье vs Доход")
plt.show()

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

lr = LinearRegression()
lr.fit(X_train, y_train)
lr_preds = lr.predict(X_test)

lr_mae = mean_absolute_error(y_test, lr_preds)
lr_rmse = mean_squared_error(y_test, lr_preds, squared=False)
lr_r2 = r2_score(y_test, lr_preds)

print("Linear Regression:")
print("MAE:", lr_mae)
print("RMSE:", lr_rmse)
print("R²:", lr_r2)
# Out:
# Linear Regression:
# MAE: 0.495462022879975
# RMSE: 0.6437888926914126
# R²: 0.6017537913445683

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x=y_test, y=lr_preds, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--r')
plt.xlabel("Настоящий Score")
plt.ylabel("Предсказанный Score")
plt.title("Linear Regression: Предсказание vs Истинное значение")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

rf = RandomForestRegressor(random_state=42)
rf.fit(X_train, y_train)
rf_preds = rf.predict(X_test)

# Метрики
rf_mae = mean_absolute_error(y_test, rf_preds)
rf_rmse = mean_squared_error(y_test, rf_preds, squared=False)
rf_r2 = r2_score(y_test, rf_preds)

print("Random Forest:")
print("MAE:", rf_mae)
print("RMSE:", rf_rmse)
print("R2:", rf_r2)
# Out:
# Random Forest:
# MAE: 0.4922937500000001
# RMSE: 0.6215852349537434
# R2: 0.6287503350133744

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x=y_test, y=rf_preds, color='green')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--r')
plt.xlabel("Настоящий Score")
plt.ylabel("Предсказанный Score")
plt.title("Random Forest: Предсказание vs Истинное значение")
plt.grid(True)
plt.show()

# %% [markdown]
# ### XGBoost Regressor

# %%
#!pip install xgboost 

from xgboost import XGBRegressor

xgb = XGBRegressor(random_state=42)
xgb.fit(X_train, y_train)
xgb_preds = xgb.predict(X_test)

# Метрики
xgb_mae = mean_absolute_error(y_test, xgb_preds)
xgb_rmse = mean_squared_error(y_test, xgb_preds, squared=False)
xgb_r2 = r2_score(y_test, xgb_preds)

print("XGBoost:")
print("MAE:", xgb_mae)
print("RMSE:", xgb_rmse)
print("R2:", xgb_r2)
# Out:
# XGBoost:
# MAE: 0.469925521671772
# RMSE: 0.6337636422966277
# R2: 0.614060408418243

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(x=y_test, y=xgb_preds, color='orange')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--r')
plt.xlabel("Настоящий Score")
plt.ylabel("Предсказанный Score")
plt.title("XGBoost: Предсказание vs Истинное значение")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Сравнение моджелей

# %%
results = pd.DataFrame({
    'Model': ['Linear Regression', 'Random Forest', 'XGBoost'],
    'MAE': [lr_mae, rf_mae, xgb_mae],
    'RMSE': [lr_rmse, rf_rmse, xgb_rmse],
    'R²': [lr_r2, rf_r2, xgb_r2]
})

results.sort_values(by='RMSE')
# Out:
#                Model       MAE      RMSE        R²
# 1      Random Forest  0.492294  0.621585  0.628750
# 2            XGBoost  0.469926  0.633764  0.614060
# 0  Linear Regression  0.495462  0.643789  0.601754

# %% [markdown]
# Важность признаков для Random Forest и XGBoost

# %%
import matplotlib.pyplot as plt
features = ['gdp_per_capita', 'social_support', 'healthy_life_expectancy',
            'freedom_to_make_life_choices', 'generosity', 'perceptions_of_corruption']
rf_importances = pd.Series(rf.feature_importances_, index=features).sort_values(ascending=True)
xgb_importances = pd.Series(xgb.feature_importances_, index=features).sort_values(ascending=True)

fig, ax = plt.subplots(1, 2, figsize=(14, 5))
rf_importances.plot(kind='barh', ax=ax[0], title="Random Forest")
xgb_importances.plot(kind='barh', ax=ax[1], title="XGBoost")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Вывод
# * Лучшую точность показала модель XGBoost, но и Random Forest дал хорошие результаты.
# * Linear Regression показал слабейшие результаты, т.к. не учитывает нелинейные связи.
# * Основные факторы, влияющие на уровень счастья: Social Support .
